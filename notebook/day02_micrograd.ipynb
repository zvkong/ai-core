# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
from src.z2h.micrograd_pytorch.value import Value

a = Value(2.0, label="a")
b = Value(3.0, label="b")
c = a * b
d = c + a
e = d.tanh()

# %%
print(a.data)
print(b.data)
print(c.data)
print(d.data)
print(e.data)
# Out:
# 2.0
# 3.0
# 6.0
# 8.0
# 0.9999997749296758

# %%
e.backward()
print(a.grad)
print(b.grad)
print(c.grad)
print(d.grad)
print(e.grad)
# Out:
# 1.8005623907413337e-06
# 9.002811953706669e-07
# 4.5014059768533343e-07
# 4.5014059768533343e-07
# 1.0
