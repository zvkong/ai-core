# %% [markdown]
# # Day 01: Two Sum
# **Source File:** `day01_two_sum.py`
#
# Implementation for finding two numbers that add up to a specific target.

# %%
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        seen = {}
        
        for i, num in enumerate(nums):
            complement = target - num
            
            if complement in seen:
                return [seen[complement], i]
            
            seen[num] = i
            
        return []

# %% [markdown]
# ---
# # Day 02: Contains Duplicate
# **Source File:** `day02_contains_duplicate.py`
#
# Implementation to check if an array contains any duplicate elements.

# %%
class Solution(object):
    def containsDuplicate(self, nums):
        """
        :type nums: List[int]
        :rtype: bool
        """
        visited = set()
        for num in nums:
            if num in visited:
                return True
            visited.add(num)

        return False

# %% [markdown]
# ---
# # Day 03: Is Anagram
# **Source File:** `day03_is_anagram.ipynb`
#
# Implementation to determine if two strings are anagrams of each other.

# %%
# class Solution(object):
#     def isAnagram(self, s, t):
#         """
#         :type s: str
#         :type t: str
#         :rtype: bool
#         """
#         counts_s = {}
#         counts_t = {}
#         for letter in s:
#             counts_s[letter] = counts_s.get(letter, 0) + 1
#         for letter in t:
#             counts_t[letter] = counts_t.get(letter, 0) + 1
#         if counts_s == counts_t:
#             return True
#         else:
#             return False
            
        
class Solution(object):
    def isAnagram(self, s, t):
        """
        :type s: str
        :type t: str
        :rtype: bool
        """
        counts = {}
        if len(s) != len(t):
            return False
        else:
            for i in s:
                counts[i] = counts.get(i, 0) + 1
            for j in t:
                counts[j] = counts.get(j, 0) - 1
            for val in counts.values():
                if val != 0:
                    return False
            else:
                return True

# %% [markdown]
# ---
# # Day 04: Valid Parentheses
# **Source File:** `day04_valid_parentheses.py`
#
# Implementation using a stack to validate the pairing of parentheses.

# %%
class Solution(object):
    def isValid(self, s):
        """
        :type s: str
        :rtype: bool
        """
        stack = []
        brackets = { ')':'(', '}':'{', ']':'['}
        for char in s:
            if char in ['(', '[', '{']:
                stack.append(char)
            
            elif char in brackets:
                if len(stack) == 0:
                    return False
            
                top = stack.pop()
                if top != brackets[char]:
                    return False
            else:
                continue

        return len(stack) == 0

# %% [markdown]
# ---
# # Day 11: Min Stack
# **Source File:** `day11_min_stack.py`
#
# Implementation of a stack that supports push, pop, top, and retrieving the minimum element in constant time.

# %%
class MinStack:

    def __init__(self):
        self.stack = []

    def push(self, val: int) -> None:
        if not self.stack:
            self.stack.append((val, val))
        else:
            prev_min = self.stack[-1][1]
            current_min = min(prev_min, val)
            self.stack.append((val, current_min))
    def pop(self) -> None:
        return self.stack.pop()

    def top(self) -> int:
        return self.stack[-1][0]

    def getMin(self) -> int:
        return self.stack[-1][1]
        


# Your MinStack object will be instantiated and called as such:
obj = MinStack()
val = 2
obj.push(val)
obj.pop()
param_3 = obj.top()
param_4 = obj.getMin()
param_3
param_4

l = [1,2,3,4,5]
min(l)

# %% [markdown]
# ---
# # Day 12 Subarray Sum Equals K
